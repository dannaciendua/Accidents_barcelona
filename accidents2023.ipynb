# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
accidents_causa= pd.read_csv("/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/translated_content_accidents_causa.csv")
accidents_persona= pd.read_csv("/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/translated_content_accidents_persones.csv")
accidents_vehicles= pd.read_csv("/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/translated_content_accidents_vehicles.csv")

# %%
accidents_causa.head()
# Out:
#        Case_Number  District_Code District_Name  Neighborhood_Code  \
# 0  2023S000699                 -1       Unknown                 -1
# 1  2023S005197                 -1       Unknown                 -1
# 2  2023S007430                 -1       Unknown                 -1
# 3  2023S000961                 -1       Unknown                 -1
# 4  2023S006486                 -1       Unknown                 -1
#
#   Neighborhood_Name  Street_Code  \
# 0           Unknown           -1
# 1           Unknown           -1
# 2           Unknown           -1
# 3           Unknown           -1
# 4           Unknown           -1
#
#                                          Street_Name Postal_Code Day_of_Week  \
# 0  Rovira (ascendent)                            ...  0             Saturday
# 1  Estatut de Catalunya                          ...  11              Friday
# 2  Rovira (ascendent)                            ...  0               Friday
# ...

# %%
accidents_causa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8897 entries, 0 to 8896
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Numero_expedient          8897 non-null   object
#  1   Codi_districte            8897 non-null   int64
#  2   Nom_districte             8897 non-null   object
#  3   Codi_barri                8897 non-null   int64
#  4   Nom_barri                 8897 non-null   object
#  5   Codi_carrer               8897 non-null   int64
#  6   Nom_carrer                8897 non-null   object
#  7   Num_postal                8893 non-null   object
#  8   Descripcio_dia_setmana    8897 non-null   object
#  9   NK_Any                    8897 non-null   int64
#  10  Mes_any                   8897 non-null   int64
#  11  Nom_mes                   8897 non-null   object
#  12  Dia_mes                   8897 non-null   int64
#  13  Hora_dia                  8897 non-null   int64
# ...

# %%
accidents_persona.head()
# Out:
#        Case_Number  District_Code   District_Name  Neighborhood_Code  \
# 0  2023S000001                  3  Sants-Montjuïc                 18
# 1  2023S000003                  1    Ciutat Vella                  1
# 2  2023S000005                  6          Gràcia                 31
# 3  2023S000006                  6          Gràcia                 31
# 4  2023S000007                  3  Sants-Montjuïc                 12
#
#             Neighborhood_Name  Street_Code  \
# 0                       Sants        30602
# 1                    el Raval        67307
# 2           la Vila de Gràcia       282401
# 3           la Vila de Gràcia       206403
# 4  la Marina del Prat Vermell          180
#
#                                          Street_Name Postal_Code Day_of_Week  \
# 0                                              Badal   0186 0186    Diumenge
# 1                                              Carme   0075 0079    Diumenge
# ...

# %%
accidents_persona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8776 entries, 0 to 8775
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Numero_expedient                         8776 non-null   object
#  1   Codi_districte                           8776 non-null   int64
#  2   Nom_districte                            8776 non-null   object
#  3   Codi_barri                               8776 non-null   int64
#  4   Nom_barri                                8776 non-null   object
#  5   Codi_carrer                              8776 non-null   int64
#  6   Nom_carrer                               8776 non-null   object
#  7   Num_postal                               8776 non-null   object
#  8   Descripcio_dia_setmana                   8776 non-null   object
#  9   NK_ Any                                  8776 non-null   int64
# ...

# %%
accidents_vehicles.head()
# Out:
#        Case_Number  District_Code District_Name  Neighborhood_Code  \
# 0  2023S000536                 -1       Unknown                 -1
# 1  2023S000506                 -1       Unknown                 -1
# 2  2023S000506                 -1       Unknown                 -1
# 3  2023S001678                 -1       Unknown                 -1
# 4  2023S002486                 -1       Unknown                 -1
#
#   Neighborhood_Name  Street_Code  \
# 0           Unknown           -1
# 1           Unknown           -1
# 2           Unknown           -1
# 3           Unknown           -1
# 4           Unknown           -1
#
#                                          Street_Name Postal_Code Day_of_Week  \
# 0  Motors / Acer                                 ...         NaN    Thursday
# 1  Motors                                        ...  152-154       Thursday
# 2                                                NaN         NaN    Thursday
# ...

# %%
accidents_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14361 entries, 0 to 14360
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Numero_expedient          14357 non-null  object
#  1   Codi_districte            14361 non-null  int64
#  2   Nom_districte             14361 non-null  object
#  3   Codi_barri                14361 non-null  int64
#  4   Nom_barri                 14361 non-null  object
#  5   Codi_carrer               14361 non-null  int64
#  6   Nom_carrer                14290 non-null  object
#  7   Num_postal                14257 non-null  object
#  8   Descripcio_dia_setmana    14361 non-null  object
#  9   NK_Any                    14361 non-null  int64
#  10  Mes_any                   14361 non-null  int64
#  11  Nom_mes                   14361 non-null  object
#  12  Dia_mes                   14361 non-null  int64
# ...

# %%
# Out:
# Missing values in Accidents Causes dataset:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Check for missing values in each dataset
#       2 print("Missing values in Accidents Causes dataset:")
# ----> 3 print(df_1.isnull().sum())
#       5 print("\nMissing values in Accidents People dataset:")
#       6 print(df_2.isnull().sum())
#
# NameError: name 'df_1' is not defined
