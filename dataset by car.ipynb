# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import numpy as np

# %%
accidents_by_vehicles2020 = pd.read_csv('/Users/anastasiasadova/Desktop/2020_accidents_vehicles_gu_bcn.csv')

# %%
accidents_by_vehicles2020
# Out:
#       Numero_expedient  Codi_districte   Nom_districte  Codi_barri  \
# 0      2020S000001                   7  Horta-Guinardó          36
# 1      2020S000002                   3  Sants-Montjuïc          16
# 2      2020S000003                   2        Eixample           8
# 3      2020S000003                   2        Eixample           8
# 4      2020S000004                   4       Les Corts          19
# ...                ...             ...             ...         ...
# 11694  2020S006276                   1    Ciutat Vella           2
# 11695  2020S006276                   1    Ciutat Vella           2
# 11696  2020S006277                   2        Eixample           9
# 11697  2020S006278                   8      Nou Barris          44
# 11698  2020S006278                   8      Nou Barris          44
#
#                              Nom_barri  Codi_carrer           Nom_carrer  \
# 0                 la Font d'en Fargues       194406             Maragall
# 1                           la Bordeta       169409      Corts Catalanes
# 2      l'Antiga Esquerra de l'Eixample       320704               Sarrià
# 3      l'Antiga Esquerra de l'Eixample       320704               Sarrià
# 4                            les Corts       101904       Doctor Fleming
# ...                                ...          ...                  ...
# 11694                   el Barri Gòtic       701266  Litoral (Llobregat)
# 11695                   el Barri Gòtic       701266  Litoral (Llobregat)
# 11696   la Nova Esquerra de l'Eixample        18505                Aragó
# 11697    Vilapicina i la Torre Llobeta        45701               Quinze
# 11698    Vilapicina i la Torre Llobeta        45701               Quinze
#
#       Num_postal Descripcio_dia_setmana Dia_setmana  ...  \
# 0      0353 0355               Dimecres          Dc  ...
# 1      0203 0203               Dimecres          Dc  ...
# 2      0018 0018               Dimecres          Dc  ...
# 3      0018 0018               Dimecres          Dc  ...
# 4      0002 0002               Dimecres          Dc  ...
# ...          ...                    ...         ...  ...
# 11694    1070000                 Dijous          Dj  ...
# 11695    1070000                 Dijous          Dj  ...
# 11696  0127 0127                 Dijous          Dj  ...
# 11697  0007 0007                Dimarts          Dm  ...
# 11698  0007 0007                Dimarts          Dm  ...
#
#                 Descripcio_tipus_vehicle       Descripcio_model  \
# 0                                Turisme  C4 CACTUS BLUEHDI 100
# 1                                   Taxi                V 220 D
# 2                            Motocicleta                 YP250R
# 3                                Turisme                  LODGY
# 4                                Turisme                   LEON
# ...                                  ...                    ...
# 11694                        Motocicleta       AGILITY CITY 125
# 11695  Veh. mobilitat personal amb motor             Desconegut
# 11696                        Motocicleta                 SH 150
# 11697                            Turisme                   CLIO
# 11698                            Turisme                  RAPID
#
#        Descripcio_marca Descripcio_color  Descripcio_carnet  \
# 0               CITROEN       Desconegut                  B
# 1         MERCEDES-BENZ       Negre/Groc                  B
# 2                YAMAHA            Negre                  A
# 3                 DACIA       Negre/Groc                  B
# 4                  SEAT             Gris                  B
# ...                 ...              ...                ...
# 11694             KYMCO       Desconegut                  B
# 11695        Desconegut            Negre         Desconegut
# 11696             HONDA          Vermell                  A
# 11697           RENAULT            Blanc         Desconegut
# 11698             SKODA       Negre/Groc         Desconegut
#
#        Antiguitat_carnet Coordenada_UTM_X Coordenada_UTM_Y    Latitud  \
# 0                      4        430501.45       4586751.53  41.427474
# 1                     11        428225.71       4580279.72  41.368985
# 2                     24        428532.59       4582672.59  41.390564
# 3                      9        428532.59       4582672.59  41.390564
# 4                      4        427929.13       4582767.09  41.391361
# ...                  ...              ...              ...        ...
# 11694                 16        431410.40       4581077.37  41.376447
# 11695         Desconegut        431410.40       4581077.37  41.376447
# 11696                 25        429362.84       4581954.15  41.384166
# 11697         Desconegut        431221.22       4586654.09  41.426658
# 11698         Desconegut        431221.22       4586654.09  41.426658
#
#        Longitud
# 0      2.167116
# 1      2.140650
# 2      2.144037
# 3      2.144037
# 4      2.136808
# ...         ...
# 11694  2.178636
# 11695  2.178636
# 11696  2.154051
# 11697  2.175740
# 11698  2.175740
#
# [11699 rows x 28 columns]

# %% [markdown]
# Options for dropna:
# dropna(how='any') (Default): Drops rows with any NaN value.
# dropna(how='all'): Drops rows only if all values are NaN.
# dropna(subset=['Column1', 'Column2']): Drops rows with NaN values in specific columns.
#
# #in case I want to plot nun values
#
#
# plt.figure(figsize=(12, 8))
# sns.heatmap(accidents_by_vehicles2023.isnull(), cbar=False, cmap='viridis')
# plt.title('Heatmap of Missing Values')
# plt.xlabel('Columns')
# plt.ylabel('Rows')
# plt.show()

# %%
accidents_by_vehicles2020.isnull().sum()
# Out:
# Numero_expedient            0
# Codi_districte              0
# Nom_districte               0
# Codi_barri                  0
# Nom_barri                   0
# Codi_carrer                 0
# Nom_carrer                  0
# Num_postal                  0
# Descripcio_dia_setmana      0
# Dia_setmana                 0
# Descripcio_tipus_dia        0
# NK_Any                      0
# Mes_any                     0
# Nom_mes                     0
# Dia_mes                     0
# Hora_dia                    0
# Descripcio_torn             0
# Descripcio_causa_vianant    0
# Descripcio_tipus_vehicle    0
# Descripcio_model            1
# Descripcio_marca            0
# Descripcio_color            0
# Descripcio_carnet           0
# Antiguitat_carnet           0
# Coordenada_UTM_X            0
# Coordenada_UTM_Y            0
# Latitud                     0
# Longitud                    0
# dtype: int64

# %%
accidents_by_vehicles2020 = accidents_by_vehicles2020.dropna()

# %%
accidents_by_vehicles2020 = accidents_by_vehicles2020.drop_duplicates()

# %%
#accidents_by_vehicles2020.to_csv('/Users/anastasiasadova/Desktop/accidents_by_vehicles2020.csv', index=False)
