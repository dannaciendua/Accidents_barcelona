# %%
# !pip install psycopg2-binary
import psycopg2
from getpass import getpass
import pandas as pd
import psycopg2
import pandas.io.sql as sqlio

# Prompt for the password securely
password = getpass("Enter your database password: ")


connection = psycopg2.connect(
    database="2023_accidents_barcelona_sql", 
    host="localhost", 
    user="postgres",
    password="password",
    port="1234"
)

data = sqlio.read_sql_query("SELECT * FROM by_cause_2023", connection)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 18.3 MB/s eta 0:00:00a 0:00:01
# ...
# Enter your database password:  ········
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 12
#       8 # Prompt for the password securely
#       9 password = getpass("Enter your database password: ")
# ---> 12 connection = psycopg2.connect(
#      13     database="2023_accidents_barcelona_sql",
#      14     host="localhost",
#      15     user="postgres",
#      16     password="password",
#      17     port="1234"
#      18 )
#      20 data = sqlio.read_sql_query("SELECT * FROM by_cause_2023", connection)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
# ...

# %%
import psycopg2
import pandas as pd
from IPython.display import display
# !pip install pandas sqlalchemy psycopg2
from pandas.io import sql as sqlio
from matplotlib import pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import numpy as np

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
connection = psycopg2.connect(
        dbname="2023_accidents_barcelona_sql",
        user="postgres",
        password="1234",
        host="localhost",
        port="5432"
    )



    # Execute SQL query and fetch data into a Pandas DataFrame
data = sqlio.read_sql_query("SELECT * FROM by_cause_2023", connection)
data
# Out:
# /var/folders/2b/p_02_vw56dz2qcq7yt8y1xh40000gn/T/ipykernel_12776/3612337946.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = sqlio.read_sql_query("SELECT * FROM by_cause_2023", connection)
#           Case_Number  District_Code District_Name  Neighborhood_Code  \
# 0     2023S000699                 -1       Unknown                 -1
# 1     2023S005197                 -1       Unknown                 -1
# 2     2023S007430                 -1       Unknown                 -1
# 3     2023S000961                 -1       Unknown                 -1
# 4     2023S006486                 -1       Unknown                 -1
# ...               ...            ...           ...                ...
# 7716  2023S004343                  9   Sant Andreu                 61
# ...

# %%
import pandas as pd 

accidents_by_vehicle2023 = pd.read_csv('/Users/anastasiasadova/Desktop/files_git/accidents_by_vehicle2020notduplicated.csv')

accidents_people2023 = pd.read_csv('/Users/dannaciendua/Documents/CodeOp/group_project/Accidents_barcelona/Preprocessed_datasets2023/2023_accidents_persona_cleaned.csv')

accidents_cause2023 = pd.read_csv('/Users/dannaciendua/Documents/CodeOp/group_project/Accidents_barcelona/Preprocessed_datasets2023/2023_accidents_causa_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# ...
