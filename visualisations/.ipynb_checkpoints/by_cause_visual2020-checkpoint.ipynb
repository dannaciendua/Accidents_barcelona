# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import numpy as np
from getpass import getpass
import psycopg2
import pandas.io.sql as sqlio

# %%
accidents_by_cause2020  = pd.read_csv('/Users/anastasiasadova/Desktop/files_git/accidents_by_cause2020edited.csv')

# %%
accidents_by_cause2020.dtypes
# Out:
# Case_Number                  object
# District_Name                object
# Neighborhood_Name            object
# Street_Name                  object
# Day_of_Week                  object
# Year                          int64
# Month_Number                  int64
# Month_Name                   object
# Day_of_Month                  int64
# Hour_of_Day                   int64
# Driver_Cause_Description     object
# Shift_Description            object
# Coordenada_UTM_X_ED50       float64
# Coordenada_UTM_Y_ED50       float64
# Longitud                    float64
# Latitud                     float64
# datetime                     object
# dtype: object

# %%
accidents_by_cause2020
# Out:
#       Case_Number District_Name              Neighborhood_Name  \
# 0     2020S001281       Unknown                        Unknown
# 1     2020S002367       Unknown                        Unknown
# 2     2020S005723    Sant Martí     el Camp de l'Arpa del Clot
# 3     2020S000847    Sant Martí     el Camp de l'Arpa del Clot
# 4     2020S003120    Sant Martí     el Camp de l'Arpa del Clot
# ...           ...           ...                            ...
# 6251  2020S000959    Nou Barris  Vilapicina i la Torre Llobeta
# 6252  2020S000242    Nou Barris  Vilapicina i la Torre Llobeta
# 6253  2020S001025    Nou Barris            el Turó de la Peira
# 6254  2020S003737    Nou Barris                          Porta
# 6255  2020S000309    Nou Barris                          Porta
#
#            Street_Name Day_of_Week  Year  Month_Number Month_Name  \
# 0      Corts Catalanes   Wednesday  2020             2   February
# 1        Molins de Rei    Saturday  2020             5        May
# 2        Independència   Wednesday  2020            12   December
# 3              Còrsega     Tuesday  2020             2   February
# 4        Independència      Monday  2020             7       July
# ...                ...         ...   ...           ...        ...
# 6251           Escòcia    Saturday  2020             2   February
# 6252           Escòcia      Sunday  2020             1    January
# 6253              Cadí      Monday  2020             2   February
# 6254   Pintor Alsamora   Wednesday  2020             8     August
# 6255  Escultor Ordóñez   Wednesday  2020             1    January
#
#       Day_of_Month  Hour_of_Day           Driver_Cause_Description  \
# 0               19           22          Disobeying traffic lights
# 1               30           12                             Others
# 2                2           13                             Others
# 3                4            6    Lack of attention while driving
# 4               13           14          Disobeying traffic lights
# ...            ...          ...                                ...
# 6251             8            6          Improper or careless turn
# 6252            12           20                             Others
# 6253            10            9  Lack of precaution when reversing
# 6254            19           19                             Others
# 6255            15           11           Disobeying other signals
#
#      Shift_Description  Coordenada_UTM_X_ED50  Coordenada_UTM_Y_ED50  \
# 0                Night              432561.42             4584522.58
# 1              Morning              422891.03             4584730.23
# 2              Morning              431461.53             4584551.41
# 3              Morning              431597.10             4585085.49
# 4            Afternoon              431372.38             4585035.95
# ...                ...                    ...                    ...
# 6251           Morning              431926.84             4586869.18
# 6252         Afternoon              431514.05             4586864.21
# 6253           Morning              430607.68             4587157.78
# 6254         Afternoon              431781.49             4587486.66
# 6255           Morning              431415.39             4587875.93
#
#       Longitud    Latitud             datetime
# 0     2.193119  41.409423  2020-02-19 22:00:00
# 1     2.077403  41.410423  2020-05-30 12:00:00
# 2     2.179957  41.409589  2020-12-02 13:00:00
# 3     2.181518  41.414411  2020-02-04 06:00:00
# 4     2.178835  41.413946  2020-07-13 14:00:00
# ...        ...        ...                  ...
# 6251  2.185263  41.430504  2020-02-08 06:00:00
# 6252  2.180323  41.430424  2020-01-12 20:00:00
# 6253  2.169443  41.432991  2020-02-10 09:00:00
# 6254  2.183454  41.436053  2020-08-19 19:00:00
# 6255  2.179028  41.439528  2020-01-15 11:00:00
#
# [6256 rows x 17 columns]

# %%
print(accidents_by_cause2020['Case_Number'].duplicated().sum())
# Out:
# 0

# %%
# Count the top 10 Driver_Cause_Description occurrences
top_10_causes = accidents_by_cause2020['Driver_Cause_Description'].value_counts().head(10)

# Display the result
top_10_causes
# Out:
# Others                                 1433
# Lack of attention while driving        1285
# Not respecting distances                753
# Improper or careless turn               576
# Disobeying traffic lights               570
# Changing lanes without caution          470
# Disobeying other signals                380
# Lack of precaution entering traffic     198
# Not respecting pedestrian crossings     186
# Lack of precaution when reversing       166
# Name: Driver_Cause_Description, dtype: int64

# %%
# I have decided to show visualisation without others
top_10_causes_filtered = top_10_causes[top_10_causes.index != 'Others']

# %%
plt.figure(figsize=(10, 6))
top_10_causes_filtered.plot(kind='bar', color='skyblue')
plt.title('Top 10 Driver Causes of Accidents (Excluding Others) 2020')
plt.xlabel('Driver Cause Description')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Group and sum accidents by Street_Name and Driver_Cause_Description
top_streets = (accidents_by_cause2020.groupby(['Street_Name', 'Driver_Cause_Description'])
                     .size()
                     .reset_index(name='Count')
                     .sort_values('Count', ascending=False)
                     .head(20))
top_streets
# Out:
#               Street_Name         Driver_Cause_Description  Count
# 604       Corts Catalanes         Not respecting distances     88
# 607       Corts Catalanes                           Others     69
# 600       Corts Catalanes  Lack of attention while driving     62
# 685              Diagonal                           Others     57
# 100                 Aragó         Not respecting distances     51
# 683              Diagonal         Not respecting distances     51
# 680              Diagonal  Lack of attention while driving     48
# 96                  Aragó        Improper or careless turn     40
# 654          Dalt (Besòs)         Not respecting distances     39
# 1291  Litoral (Llobregat)  Lack of attention while driving     37
# 653          Dalt (Besòs)  Lack of attention while driving     37
# 676              Diagonal        Disobeying traffic lights     35
# 1282      Litoral (Besòs)  Lack of attention while driving     35
# 102                 Aragó                           Others     34
# 98                  Aragó  Lack of attention while driving     34
# 595       Corts Catalanes   Changing lanes without caution     33
# 1494            Meridiana  Lack of attention while driving     32
# 2402             València                           Others     32
# 93                  Aragó   Changing lanes without caution     31
# 1284      Litoral (Besòs)         Not respecting distances     29

# %%
# Most popular street in this data set is Corts Catalanes and
# most common reason for accidents on the street "Corts Catalanes", excluding unspecified causes like "Others"

les_corts_data = accidents_by_cause2020[
    (accidents_by_cause2020['Street_Name'] == 'Corts Catalanes') &
    (accidents_by_cause2020['Driver_Cause_Description'] != 'Others')
]
   
main_cause = les_corts_data['Driver_Cause_Description'].value_counts().idxmax()
main_cause_count = les_corts_data['Driver_Cause_Description'].value_counts().max()

main_cause_count, main_cause
# Out:
# (88, 'Not respecting distances')

# %%
top_5_causes = les_corts_data['Driver_Cause_Description'].value_counts().head(5)

# %%
top_5_causes
# Out:
# Not respecting distances           88
# Lack of attention while driving    62
# Changing lanes without caution     33
# Disobeying traffic lights          28
# Improper or careless turn          27
# Name: Driver_Cause_Description, dtype: int64

# %%
# Filter data for the specific street, excluding 'Others' in 'Driver_Cause_Description'
les_corts_data = accidents_by_cause2020[
    (accidents_by_cause2020['Street_Name'] == 'Corts Catalanes') &
    (accidents_by_cause2020['Driver_Cause_Description'] != 'Others')
]

# Get the top 5 most common causes
top_5_causes_for_granvia = les_corts_data['Driver_Cause_Description'].value_counts().head(5)

# Plot the data
plt.figure(figsize=(10, 6))
top_5_causes_for_granvia.plot(kind='bar', color='skyblue', edgecolor='black')

# Add titles and labels
plt.title('Top 5 Accident Causes on Corts Catalanes (Excluding Others) 2020', fontsize=16)
plt.xlabel('Driver Cause Description', fontsize=12)
plt.ylabel('Number of Accidents', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()

# %%
accidents_by_month = accidents_by_cause2020.groupby('Month_Name').size()

accidents_by_month = accidents_by_month.reindex(months_order)

# Plot the data
plt.figure(figsize=(10, 6))
accidents_by_month.plot(kind='bar', color='skyblue', alpha=0.8)

plt.title('Total Accidents by Month', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Number of Accidents', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7p/zttb20215d97cqdshpnkph4r0000gn/T/ipykernel_2977/2925455129.py in <module>
#       1 accidents_by_month = accidents_by_cause2020.groupby('Month_Name').size()
#       2
# ----> 3 accidents_by_month = accidents_by_month.reindex(months_order)
#       4
#       5 # Plot the data
#
# NameError: name 'months_order' is not defined

# %%
# Find the most popular month based on the total number of accidents
most_popular_month = accidents_by_cause2020['Month_Name'].value_counts().idxmax()
most_popular_count = accidents_by_cause2020['Month_Name'].value_counts().max()

most_popular_month, most_popular_count
# Out:
# ('February', 775)

# %%
# Create a map centered around Barcelona as a starting point
barcelona_center = [41.3851, 2.1734]  # Coordinates for Barcelona
accident_map = folium.Map(location=barcelona_center, zoom_start=12)

# Add accident points from February data to the map as child layers
february_data = accidents_by_cause2020[accidents_by_cause2020['Month_Name'] == 'February']

# Add accident points to the map with markers
for _, row in february_data.iterrows():
    folium.CircleMarker(
        location=[row['Latitud'], row['Longitud']],
        radius=5,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6,
        popup=f"Cause: {row['Driver_Cause_Description']}"
    ).add_to(accident_map)

# Display the map in the notebook
accident_map                                                  # All Accidents February (most popular month in 2020)
#The most popular cause in February (excluding 'Others') is 'Lack of attention while driving' with 134 accidents.                                                               #All Accidents February 2020
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_172f78214a802bef8c1d3026d6f1fc8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_172f78214a802bef8c1d3026d6f1fc8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_172f78214a802bef8c1d3026d6f1fc8b = L.map(
#                 &quot;map_172f78214a802bef8c1d3026d6f1fc8b&quot;,
#                 {
#                     center: [41.3851, 2.1734],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db965d74772ad6ee7da26b1872b9fcd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db965d74772ad6ee7da26b1872b9fcd0.addTo(map_172f78214a802bef8c1d3026d6f1fc8b);
#
#
#             var circle_marker_2a288cf4bb12efb70c0bd57522384a42 = L.circleMarker(
#                 [41.4094226443517, 2.19311873803974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_172f78214a802bef8c1d3026d6f1fc8b);
#
#
#         var popup_159a6e159ae3a362af7f3680e283824c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ad45311ce186e3ac62e5aec1f44a42e = $(`&lt;div id=&quot;html_6ad45311ce186e3ac62e5aec1f44a42e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Disobeying traffic lights&lt;/div&gt;`)[0];
#                 popup_159a6e159ae3a362af7f3680e283824c.setContent(html_6ad45311ce186e3ac62e5aec1f44a42e);
#
#
#
#         circle_marker_2a288cf4bb12efb70c0bd57522384a42.bindPopup(popup_159a6e159ae3a362af7f3680e283824c)
#         ;
#
#
#
#
#             var circle_marker_d26f93714bd12fdeaab2b61bb92122f4 = L.circleMarker(
#                 [41.4144111039125, 2.18151843749033],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_172f78214a802bef8c1d3026d6f1fc8b);
#
#
#         var popup_70777b04a057474850647f238ccf4d4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae9c088786a9625c75edb98a3525abfb = $(`&lt;div id=&quot;html_ae9c088786a9625c75edb98a3525abfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Lack of attention while driving&lt;/div&gt;`)[0];
#                 popup_70777b04a057474850647f238ccf4d4c.setContent(html_ae9c088786a9625c75edb98a3525abfb);
#
#
#
#         circle_marker_d26f93714bd12fdeaab2b61bb92122f4.bindPopup(popup_70777b04a057474850647f238ccf4d4c)
#         ;
#
#
#
#
#             var circle_marker_6bee74c8c914d5228729561e0df98f7a = L.circleMarker(
#                 [41.4127346267177, 2.18201150930014],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_172f78214a802bef8c1d3026d6f1fc8b);
#
#
#         var popup_2e5808fd4439d3e1a7294ec89c0bf632 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bea26c0f3931fcedabead0de81455dc0 = $(`&lt;div id=&quot;html_bea26c0f3931fcedabead0de81455dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Disobeying other signals&lt;/div&gt;`)[0];
#                 popup_2e5808fd4439d3e1a7294ec89c0bf632.setContent(html_bea26c0f3931fcedabead0de81455dc0);
#
#
#
#         circle_marker_6bee74c8c914d5228729561e0df98f7a.bindPopup(popup_2e5808fd4439d3e1a7294ec89c0bf632)
#         ;
#
#
#
#
#             var circle_marker_a040fce44de1d738619bf070eaa8ac67 = L.circleMarker(
#                 [41.41446888786, 2.22313795233455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOf

# %%
# Exclude "Others" from the February data
february_data_filtered = february_data[february_data['Driver_Cause_Description'] != 'Others']

# Find the most popular cause in February, excluding "Others"
most_popular_cause = february_data_filtered['Driver_Cause_Description'].value_counts().idxmax()
most_popular_cause_count = february_data_filtered['Driver_Cause_Description'].value_counts().max()

# Display the result
print(f"The most popular cause in February (excluding 'Others') is '{most_popular_cause}' with {most_popular_cause_count} accidents.")
# Out:
# The most popular cause in February (excluding 'Others') is 'Lack of attention while driving' with 134 accidents.

# %%
# Create a map centered around Barcelona as a starting point
barcelona_center = [41.3851, 2.1734]  # Coordinates for Barcelona
accident_map = folium.Map(location=barcelona_center, zoom_start=12)

# Add accident points from April data to the map as child layers
april_data = accidents_by_cause2020[accidents_by_cause2020['Month_Name'] == 'April']

# Add accident points to the map with markers
for _, row in april_data.iterrows():
    folium.CircleMarker(
        location=[row['Latitud'], row['Longitud']],
        radius=5,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6,
        popup=f"Cause: {row['Driver_Cause_Description']}"
    ).add_to(accident_map)

# Display the map in the notebook
accident_map 
    #The most popular cause in April(excluding 'Others') is 'Lack of attention while driving' with 24 accidents.
                        #April 2020 was less polular month
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53e647f56eee56a7861d9e01bcadcd0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53e647f56eee56a7861d9e01bcadcd0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53e647f56eee56a7861d9e01bcadcd0b = L.map(
#                 &quot;map_53e647f56eee56a7861d9e01bcadcd0b&quot;,
#                 {
#                     center: [41.3851, 2.1734],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f6de6d9f6dfc08b3cd4730a78c28324 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4f6de6d9f6dfc08b3cd4730a78c28324.addTo(map_53e647f56eee56a7861d9e01bcadcd0b);
#
#
#             var circle_marker_f4aa528a1f805554d65468116b2dcc9d = L.circleMarker(
#                 [41.4214144420665, 2.20950135033383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53e647f56eee56a7861d9e01bcadcd0b);
#
#
#         var popup_d24d491260319c05bc41334c8ef5f0b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_78ae2cdd162c56ac1bbbc0dce5965220 = $(`&lt;div id=&quot;html_78ae2cdd162c56ac1bbbc0dce5965220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Not yielding to the right&lt;/div&gt;`)[0];
#                 popup_d24d491260319c05bc41334c8ef5f0b4.setContent(html_78ae2cdd162c56ac1bbbc0dce5965220);
#
#
#
#         circle_marker_f4aa528a1f805554d65468116b2dcc9d.bindPopup(popup_d24d491260319c05bc41334c8ef5f0b4)
#         ;
#
#
#
#
#             var circle_marker_23f27c8c124ec94074adebe6674473ad = L.circleMarker(
#                 [41.422336144915, 2.2082654735076],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53e647f56eee56a7861d9e01bcadcd0b);
#
#
#         var popup_967f1b3e866ef8cca16507295c1116fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3249789fb9881ce7f19553c3f7b1204d = $(`&lt;div id=&quot;html_3249789fb9881ce7f19553c3f7b1204d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Disobeying traffic lights&lt;/div&gt;`)[0];
#                 popup_967f1b3e866ef8cca16507295c1116fc.setContent(html_3249789fb9881ce7f19553c3f7b1204d);
#
#
#
#         circle_marker_23f27c8c124ec94074adebe6674473ad.bindPopup(popup_967f1b3e866ef8cca16507295c1116fc)
#         ;
#
#
#
#
#             var circle_marker_a147db4a484236872041114c3eace008 = L.circleMarker(
#                 [41.405976792618, 2.2142882801424],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53e647f56eee56a7861d9e01bcadcd0b);
#
#
#         var popup_2eaaa1828c5f794a3c2dc6abbb0c2f26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bc8aa5978d4a63ef82049918b6c6c1e = $(`&lt;div id=&quot;html_6bc8aa5978d4a63ef82049918b6c6c1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cause: Disobeying traffic lights&lt;/div&gt;`)[0];
#                 popup_2eaaa1828c5f794a3c2dc6abbb0c2f26.setContent(html_6bc8aa5978d4a63ef82049918b6c6c1e);
#
#
#
#         circle_marker_a147db4a484236872041114c3eace008.bindPopup(popup_2eaaa1828c5f794a3c2dc6abbb0c2f26)
#         ;
#
#
#
#
#             var circle_marker_b974c24a98735d08d061e469152d4b71 = L.circleMarker(
#                 [41.4005169632232, 2.20222887596464],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&qu

# %%
# Exclude "Others" from the April data
april_data_filtered = april_data[april_data['Driver_Cause_Description'] != 'Others']

# Find the most popular cause in April, excluding "Others"
most_popular_cause = april_data_filtered['Driver_Cause_Description'].value_counts().idxmax()
most_popular_cause_count = april_data_filtered['Driver_Cause_Description'].value_counts().max()

# Display the result
print(f"The most popular cause in April(excluding 'Others') is '{most_popular_cause}' with {most_popular_cause_count} accidents.")
# Out:
# The most popular cause in April(excluding 'Others') is 'Lack of attention while driving' with 24 accidents.

# %%
# Count occurrences of Shift_Description and Street_Name combinations
shift_street_counts = accidents_by_cause2020.groupby(['Shift_Description', 'Street_Name']).size().reset_index(name='Count')

# Sort the data to focus on the most frequent combinations
shift_street_counts = shift_street_counts.sort_values(by='Count', ascending=False).head(15)

# Plot a bar chart of the top 15 Shift_Description and Street_Name combinations
plt.figure(figsize=(12, 8))
plt.barh(
    shift_street_counts['Shift_Description'] + ' - ' + shift_street_counts['Street_Name'],
    shift_street_counts['Count']
)
plt.title('Top 15 Combinations of Shift Description and Street Name', fontsize=16)
plt.xlabel('Number of Accidents', fontsize=14)
plt.ylabel('Shift Description - Street Name', fontsize=14)
plt.gca().invert_yaxis()  # Invert y-axis to show the highest count on top
plt.tight_layout()
plt.show()

# %%
# Define true pastel colors for the chart
pastel_colors = [
    '#FFB6C1',  # Light Pink
    '#ADD8E6',  # Light Blue
    '#98FB98',  # Pale Green
    '#FFE4B5',  # Moccasin
    '#D8BFD8',  # Thistle
    '#FFDAB9',  # Peach Puff
    '#E6E6FA',  # Lavender
    '#F0E68C',  # Khaki
    '#FFFACD',  # Lemon Chiffon
    '#B0E0E6',  # Powder Blue
    '#FAFAD2',  # Light Goldenrod Yellow
    '#FFC0CB',  # Pink
    '#FFF0F5',  # Lavender Blush
    '#F5DEB3',  # Wheat
    '#FFDEAD'   # Navajo White
]

# Plot a bar chart of the top 15 Shift_Description and Street_Name combinations with pastel colors
plt.figure(figsize=(12, 8))
plt.barh(
    shift_street_counts['Shift_Description'] + ' - ' + shift_street_counts['Street_Name'],
    shift_street_counts['Count'],
    color=pastel_colors[:len(shift_street_counts)]
)
plt.title('Top 15 Combinations of Shift Description and Street Name 2020', fontsize=16)
plt.xlabel('Number of Accidents', fontsize=14)
plt.ylabel('Shift Description - Street Name', fontsize=14)
plt.gca().invert_yaxis()  # Invert y-axis to show the highest count on top
plt.tight_layout()
plt.show()

# %%
# Aggregate the counts of occurrences for each coordinate pair (latitude and longitude)
coordinate_counts = accidents_by_cause2020.groupby(['Latitud', 'Longitud']).size().reset_index(name='Count')

# Find the coordinate with the highest count
most_frequent_coordinate = coordinate_counts.nlargest(1, 'Count')

# Display the result
print(most_frequent_coordinate)
# Out:
#        Latitud  Longitud  Count
# 790  41.384036  2.148291     15

# %%
top_5_frequent_coordinates = accidents_by_cause2020[['Latitud', 'Longitud']].value_counts().head(5).reset_index(name='Count')

# %%
top_5_frequent_coordinates
# Out:
#      Latitud  Longitud  Count
# 0  41.384036  2.148291     15
# 1  41.392618  2.138226     15
# 2  41.391737  2.162972     14
# 3  41.400957  2.182301     14
# 4  41.389090  2.166454     12

# %%
map_top_5 = folium.Map(location=[41.3851, 2.1734], zoom_start=12)  # Example: Centered on Barcelona

# Add markers for the top 5 most frequent coordinates
for index, row in top_5_frequent_coordinates.iterrows():
    folium.Marker(
        location=[row['Latitud'], row['Longitud']],
        popup=f"Accidents: {row['Count']}",
    ).add_to(map_top_5)

# Display the map
map_top_5
                                                                                #top 5 most frequent points
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a79f14323fb2b06f06567a6ec1082be0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a79f14323fb2b06f06567a6ec1082be0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a79f14323fb2b06f06567a6ec1082be0 = L.map(
#                 &quot;map_a79f14323fb2b06f06567a6ec1082be0&quot;,
#                 {
#                     center: [41.3851, 2.1734],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a3934d616cd85b2999dad18312138cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2a3934d616cd85b2999dad18312138cd.addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#             var marker_b67e0c4670b08caadb391f792f654b63 = L.marker(
#                 [41.384036101859, 2.14829138183649],
#                 {}
#             ).addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#         var popup_8a41ef965a11aa4ae5b6c1db6881991e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_771f5d4b3a38cc988a57917d9d31afa9 = $(`&lt;div id=&quot;html_771f5d4b3a38cc988a57917d9d31afa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidents: 15.0&lt;/div&gt;`)[0];
#                 popup_8a41ef965a11aa4ae5b6c1db6881991e.setContent(html_771f5d4b3a38cc988a57917d9d31afa9);
#
#
#
#         marker_b67e0c4670b08caadb391f792f654b63.bindPopup(popup_8a41ef965a11aa4ae5b6c1db6881991e)
#         ;
#
#
#
#
#             var marker_3be702ff273a890b14e5b6e38aad8fc9 = L.marker(
#                 [41.3926176379381, 2.13822634422389],
#                 {}
#             ).addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#         var popup_cff1c7ebde31fc5e5b6a19222282d70c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a952b588459935c1e545f6166ab566e = $(`&lt;div id=&quot;html_2a952b588459935c1e545f6166ab566e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidents: 15.0&lt;/div&gt;`)[0];
#                 popup_cff1c7ebde31fc5e5b6a19222282d70c.setContent(html_2a952b588459935c1e545f6166ab566e);
#
#
#
#         marker_3be702ff273a890b14e5b6e38aad8fc9.bindPopup(popup_cff1c7ebde31fc5e5b6a19222282d70c)
#         ;
#
#
#
#
#             var marker_cdca0730e250f7491a7956b0ac51caa9 = L.marker(
#                 [41.391737066281, 2.1629715970784],
#                 {}
#             ).addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#         var popup_18e4450060c83d90c2a0d033adbacc63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a883105e7a89a38722772ae694d3ccd = $(`&lt;div id=&quot;html_4a883105e7a89a38722772ae694d3ccd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidents: 14.0&lt;/div&gt;`)[0];
#                 popup_18e4450060c83d90c2a0d033adbacc63.setContent(html_4a883105e7a89a38722772ae694d3ccd);
#
#
#
#         marker_cdca0730e250f7491a7956b0ac51caa9.bindPopup(popup_18e4450060c83d90c2a0d033adbacc63)
#         ;
#
#
#
#
#             var marker_f66bb4805d28ed9965ac0082b64d15b9 = L.marker(
#                 [41.4009572398813, 2.18230133868668],
#                 {}
#             ).addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#         var popup_fe481172f722d87671751bef4a02ed5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7e619b039fe8e8c3f52e461797b22b4 = $(`&lt;div id=&quot;html_d7e619b039fe8e8c3f52e461797b22b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidents: 14.0&lt;/div&gt;`)[0];
#                 popup_fe481172f722d87671751bef4a02ed5e.setContent(html_d7e619b039fe8e8c3f52e461797b22b4);
#
#
#
#         marker_f66bb4805d28ed9965ac0082b64d15b9.bindPopup(popup_fe481172f722d87671751bef4a02ed5e)
#         ;
#
#
#
#
#             var marker_35f052b69522329158e3d1b86e45bf83 = L.marker(
#                 [41.3890895514394, 2.16645422690526],
#                 {}
#             ).addTo(map_a79f14323fb2b06f06567a6ec1082be0);
#
#
#         var popup_c60391dd0cf029cf1d994ac3ba01fef8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17b2158c3da3875cdd1dc65aed9a553e = $(`&lt;div id=&quot;html_17b2158c3da3875cdd1dc65aed9a553e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Accidents: 12.0&lt;/div&gt;`)[0];
#                 popup_c60391dd0cf029cf1d994ac3ba01fef8.setContent(html_17b2158c3da3875cdd1dc65aed9a553e);
#
#
#
#         marker_35f052b69522329158e3d1b86e45bf83.bindPopup(popup_c60391dd0cf029cf1d994ac3ba01fef8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" a

# %%
# Find the most popular day of the week
most_popular_day = accidents_by_cause2020['Day_of_Week'].value_counts().idxmax()
most_popular_day_count = accidents_by_cause2020['Day_of_Week'].value_counts().max()

# Find the most popular time of day
most_popular_time = accidents_by_cause2020['Hour_of_Day'].value_counts().idxmax()
most_popular_time_count = accidents_by_cause2020['Hour_of_Day'].value_counts().max()

# Display the results
print(f"The most popular day of the week for accidents is {most_popular_day} with {most_popular_day_count} accidents.")
print(f"The most popular time of day for accidents is {most_popular_time}:00 with {most_popular_time_count} accidents.")
# Out:
# The most popular day of the week for accidents is Thursday with 1101 accidents.
# The most popular time of day for accidents is 14:00 with 503 accidents.

# %%
# Count the number of accidents on Thursday at 14:00
accidents_on_thursday_14 = accidents_by_cause2020[
    (accidents_by_cause2020['Day_of_Week'] == 'Thursday') &
    (accidents_by_cause2020['Hour_of_Day'] == 14)
].shape[0]

# Display the result
print(f"The number of accidents on Thursday at 14:00 is {accidents_on_thursday_14}.")
# Out:
# The number of accidents on Thursday at 14:00 is 95.

# %%
accidents_pivot = accidents_by_cause2020.pivot_table(
    index='Day_of_Week', 
    columns='Hour_of_Day', 
    values='Case_Number', 
    aggfunc='count'
)

# Reorder the days of the week
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
accidents_pivot = accidents_pivot.reindex(days_order)

# Plot a heatmap of accidents by day of the week and time
plt.figure(figsize=(12, 8))
sns.heatmap(accidents_pivot, cmap="YlGnBu", annot=False, cbar=True)

plt.title('Accidents by Day of the Week and Time of Day 2020', fontsize=16)
plt.xlabel('Time of Day (Hour)', fontsize=14)
plt.ylabel('Day of the Week', fontsize=14)
plt.tight_layout()
plt.show()

# %%
accidents_pivot = accidents_by_cause2020.pivot_table(
    index='Day_of_Week', 
    columns='Shift_Description', 
    values='Case_Number', 
    aggfunc='count'
)

# Reorder the days of the week
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
accidents_pivot = accidents_pivot.reindex(days_order)

# Plot a heatmap of accidents by day of the week and time
plt.figure(figsize=(12, 8))
sns.heatmap(accidents_pivot, cmap="YlGnBu", annot=False, cbar=True)

plt.title('Accidents by Day of the Week and Time of Day', fontsize=16)
plt.xlabel('Part of the day', fontsize=14)
plt.ylabel('Day of the Week', fontsize=14)
plt.tight_layout()
plt.show()
